# %% [markdown]
# # СӨЖ 2
#
#
# ### 1-бөлім: Айнымалылар және деректер типтері (1-5 тапсырмалар)
#
# **1-тапсырма:** Оқыту процесін жылдамдататын `momentum` (импульс) айнымалысын жасап, оған `0.9` мәнін беріңіз және экранға шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
momentum = 0.9
print(momentum)
# Out:
# 0.9

# %% [markdown]
# **2-тапсырма:** Активация функциясының атауын сақтайтын `activation_fn = "tanh"` мәтіндік айнымалысын құрыңыз. `len()` функциясы арқылы осы сөздің ұзындығын (әріптер санын) шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
activation_fn = "tanh"
print(len(activation_fn))
# Out:
# 4

# %% [markdown]
# **3-тапсырма:** Модельдің сапасын бағалайтын ROC қисығының астындағы ауданды (AUC) үшбұрыш ауданы арқылы жуықтап есептеңіз. `base = 1.0` және `height = 0.85` айнымалыларын көбейтіп, оны 2-ге бөліп шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
base=1.0
height=0.85
auc_roc=base*height/2
print(auc_roc)
# Out:
# 0.425

# %% [markdown]
# **4-тапсырма:** Оқытудың ағымдағы қадамы `step_number = 150` (бүтін сан) түрінде берілген. Осы санды бөлшек санға (`float`) айналдырып, `float_step` айнымалысына сақтаңыз.

# %%
# Осында кодыңызды жазыңыз
step_number = 150
float_step=float(step_number)
print(float_step)
# Out:
# 150.0

# %% [markdown]
# **5-тапсырма:** Модельдің оқытуы аяқталғанын білдіретін `is_converged = False` логикалық (boolean) айнымалысын құрып, оның деректер типін `type()` арқылы тексеріңіз.

# %%
# Осында кодыңызды жазыңыз
is_converged = False
type(is_converged)
# Out:
# bool

# %% [markdown]
# ### 2-бөлім: Шарттар (6-10 тапсырмалар)
#
# **6-тапсырма:** Градиенттің жойылуын (vanishing gradient) тексеріңіз. `gradient = 0.00001` мәні берілген. Егер градиент `0.001`-ден кіші болса, "Градиент тым аз!" деп шығаратын шарт жазыңыз.

# %%
# Осында кодыңызды жазыңыз
gradient = 0.00001
if gradient<0.001:
  print('gradient is too low')
else:
  print(f'gradient is {gradient}')
# Out:
# gradient is too low

# %% [markdown]
# **7-тапсырма:** Оқыту жылдамдығын кестелеу (LR Scheduling). Егер ағымдағы `epoch = 150` мәні 100-ден үлкен болса, `lr` айнымалысына `0.001` беріңіз, әйтпесе `0.01` беріңіз. `lr` мәнін шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
epoch = 150

if epoch > 100:
    lr = 0.001
else:
    lr = 0.01

print(lr)
# Out:
# 0.001

# %% [markdown]
# **8-тапсырма:** Dropout механизмінің симуляциясы. Кездейсоқ сан `rand_val = 0.6` және сөндіру ықтималдығы `dropout_rate = 0.5`. Егер `rand_val` мәні `dropout_rate`-тен кіші болса, "Нейрон сөндірілді", әйтпесе "Нейрон қалды" деп шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
rand_val = 0.6
dropout_rate = 0.5

if rand_val < dropout_rate:
    print("Нейрон сөндірілді")
else:
    print("Нейрон қалды")
# Out:
# Нейрон қалды

# %% [markdown]
# **9-тапсырма:** Модельдің көлемін бағалау. `params_count = 5000000` (параметрлер саны). Егер ол 10 миллионнан асса "Үлкен модель", 1 миллион мен 10 миллион арасында болса "Орташа модель", әйтпесе "Шағын модель" деп шығарыңыз (`if-elif-else`).

# %%
# Осында кодыңызды жазыңыз
param_count=5000000
if param_count>10000000:
  print('high model')
elif param_count>1000000 and param_count<=10000000:
  print('medium')
else:
  print('low')
# Out:
# medium

# %% [markdown]
# **10-тапсырма:** Ең жақсы нәтижені сақтау (Model Checkpointing). `best_accuracy = 0.88` және ағымдағы дәлдік `current_accuracy = 0.89`. Егер ағымдағы дәлдік бұрынғы ең жақсы нәтижеден асып түссе, "Жаңа ең жақсы модель сақталды" деп басып шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
best_accuracy = 0.88
current_accuracy = 0.89

if current_accuracy > best_accuracy:
    best_accuracy = current_accuracy
    print("Жаңа ең жақсы модель сақталды")
# Out:
# Жаңа ең жақсы модель сақталды

# %% [markdown]
# ### 3-бөлім: Циклдер (11-17 тапсырмалар)
#
# **11-тапсырма:** Кездейсоқ жүріс (Random Walk) симуляциясы. `range(1, 4)` арқылы `for` циклін құрып, экранға 3 рет "Қадам: X" деп шығарыңыз (мұндағы X - қадам нөмірі).

# %%
# Осында кодыңызды жазыңыз
for step in range(1, 4):
    print(f"Қадам: {step}")
# Out:
# Қадам: 1
# Қадам: 2
# Қадам: 3

# %% [markdown]
# **12-тапсырма:** Нейрондық желідегі сүзгілер санын (filters) арттыру. Бастапқы көлем `capacity = 1`. `while` циклі арқылы `capacity` мәні 32-ден асқанша оны 2-ге көбейтіп отырыңыз. Әр көбейтілген сайын мәнін шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
capacity = 1

while capacity <= 32:
    print(capacity)
    capacity *= 2
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# **13-тапсырма:** Градиенттерді жинақтау (Gradient Accumulation). `total_grad = 0` айнымалысын жасаңыз. `for` циклі мен `range(1, 6)` арқылы 1-ден 5-ке дейінгі сандарды `total_grad`-қа қосып отырыңыз. Соңында нәтижені шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
total_grad = 0

for i in range(1, 6):
    total_grad += i  # әр қадамдағы градиентті қосу

print(total_grad)
# Out:
# 15

# %% [markdown]
# **14-тапсырма:** Оқыту алдындағы кері санақ. `for` циклі мен `range(5, 0, -1)` функциясын пайдаланып, 5-тен 1-ге дейін кері санап шығыңыз, соңында "Оқыту басталды!" деп жазыңыз.

# %%
# Осында кодыңызды жазыңыз
for i in range(5, 0, -1):
    print(i)
print("Оқыту басталды!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Оқыту басталды!

# %% [markdown]
# **15-тапсырма:** Оңтайлы гиперпараметрді іздеу симуляциясы. `range(1, 20)` ішінде цикл жүргізіп, 7-ге қалдықсыз бөлінетін бірінші санды тапқан кезде оны экранға шығарып, `break` арқылы циклді тоқтатыңыз.

# %%
# Осында кодыңызды жазыңыз
for i in range(1, 20):
    if i % 7 == 0:
        print(i)
        break
# Out:
# 7

# %% [markdown]
# **16-тапсырма:** Есептеулерді өткізіп жіберу. `range(1, 6)` циклінде, егер қадам `4`-ке тең болса, `continue` арқылы оны өткізіп жіберіп, қалған қадамдарды экранға шығарыңыз.

# %%
# Осында кодыңызды жазыңыз
for step in range(1, 6):
    if step == 4:
        continue  # 4-ші қадамды өткізіп жіберу
    print(step)
# Out:
# 1
# 2
# 3
# 5

# %% [markdown]
# **17-тапсырма:** Q-learning алгоритміндегі эпсилонды (Epsilon) азайту. Бастапқы `epsilon = 1.0`. `while` циклі арқылы `epsilon` мәні `0.1`-ден үлкен болғанша одан `0.2`-ні алып тастап отырыңыз.

# %%
# Осында кодыңызды жазыңыз
epsilon = 1.0

while epsilon > 0.1:
    print(round(epsilon, 1))
    epsilon -= 0.2
# Out:
# 1.0
# 0.8
# 0.6
# 0.4
# 0.2

# %% [markdown]
# ### 4-бөлім: Функциялар, аргументтер және қайтару мәндері (18-25 тапсырмалар)
#
# **18-тапсырма:** Сызықтық активация функциясы. Қандай сан қабылдаса, дәл сол санды еш өзгеріссіз қайтаратын `identity_activation(x)` функциясын жазыңыз.

# %%
# Осында кодыңызды жазыңыз
def identity_activation(x):
    return x
print(identity_activation(5))
# Out:
# 5

# %% [markdown]
# **19-тапсырма:** Оптимизатордағы импульсті жаңарту. Үш аргумент (`velocity`, `gradient`, `momentum`) қабылдап, `(momentum * velocity) + gradient` формуласымен жаңа жылдамдықты қайтаратын функция жазыңыз.

# %%
# Осында кодыңызды жазыңыз
def update_velocity(velocity, gradient, momentum):
    return (momentum * velocity) + gradient
v = 0.5
g = 0.1
m = 0.9

new_v = update_velocity(v, g, m)
print(new_v)  # Нәтиже: 0.55
# Out:
# 0.55

# %% [markdown]
# **20-тапсырма:** Leaky ReLU активациясы. Екі аргумент: `x` және әдепкі мәні `0.01` болатын `alpha` қабылдайтын `leaky_relu` функциясын жасаңыз. Егер `x > 0` болса `x`-ті, әйтпесе `x * alpha` мәнін қайтарыңыз.

# %%
# Осында кодыңызды жазыңыз
def leaky_relu(x, alpha=0.01):
    if x > 0:
        return x
    else:
        return x * alpha

print(leaky_relu(5))
# Out:
# 5

# %% [markdown]
# **21-тапсырма:** Дәлдікті (Accuracy) есептеу. `correct_predictions` және `total_predictions` аргументтерін қабылдап, олардың қатынасын қайтаратын функция жазыңыз. Егер `total_predictions` нөлге тең болса, `0` қайтаратын шарт қосыңыз.

# %%
# Осында кодыңызды жазыңыз
def compute_accuracy(correct_predictions, total_predictions):
    if total_predictions == 0:
        return 0
    return correct_predictions / total_predictions
print(compute_accuracy(45, 50))
# Out:
# 0.9

# %% [markdown]
# **22-тапсырма:** Асыра сілтеуді (Overfitting) тексеру. `train_loss` және `val_loss` қабылдайтын логикалық функция жазыңыз. Егер валидациялық қателік оқыту қателігінен үлкен болса `True`, әйтпесе `False` қайтарыңыз.

# %%
# Осында кодыңызды жазыңыз
def is_overfitting(train_loss, val_loss):
    return val_loss > train_loss
print(is_overfitting(0.2, 0.5))
# Out:
# True

# %% [markdown]
# **23-тапсырма:** Деректерді стандарттау (Z-score). `value`, `mean` (орташа мән) және `std` (стандартты ауытқу) аргументтерін қабылдап, `(value - mean) / std` формуласы бойынша жаңа мәнді қайтаратын `standardize_feature` функциясын құрыңыз.

# %%
# Осында кодыңызды жазыңыз
#(Xi-mean)/std
def standardize_feature(value, mean, std):
    return (value - mean) / std
print(standardize_feature(10, 5, 2))
# Out:
# 2.5

# %% [markdown]
# **24-тапсырма:** Оқыту фазасын анықтау. `epoch` (дәуір) аргументін қабылдап, егер ол 5-тен кіші болса "Warmup" (Қыздыру) мәтінін, әйтпесе "Fine-tuning" (Нақты баптау) мәтінін қайтаратын функция жазыңыз.

# %%
# Осында кодыңызды жазыңыз
def training_phase(epoch):
    if epoch < 5:
        return "Warmup"
    else:
        return "Fine-tuning"
print(training_phase(2))
# Out:
# Warmup

# %% [markdown]
# **25-тапсырма:** Huber Loss қателігінің қарапайым нұсқасы. `error` және `delta` аргументтерін қабылдайтын функция жазыңыз. Егер қателіктің абсолюттік мәні (`abs(error)`) `delta`-дан кіші немесе тең болса, `0.5 * error ** 2` қайтарыңыз. Әйтпесе, `delta * abs(error) - 0.5 * delta ** 2` формуласын қайтарыңыз.

# %%
# Осында кодыңызды жазыңыз
def huber_loss(error, delta):
    if abs(error) <= delta:
        return 0.5 * error ** 2
    else:
        return delta * abs(error) - 0.5 * delta ** 2
print(huber_loss(2, 1))
# Out:
# 1.5
